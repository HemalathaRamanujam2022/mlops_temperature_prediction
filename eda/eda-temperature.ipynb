# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
input_file = "data/london_weather.csv"
df = pd.read_csv(input_file, parse_dates=True)

# %%
print("\nFirst 5 Rows:\n", df.head())
# Out:
# First 5 Rows:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
df.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
df.columns
# Out:
# Index(['date', 'cloud_cover', 'sunshine', 'global_radiation', 'max_temp',
#        'mean_temp', 'min_temp', 'precipitation', 'pressure', 'snow_depth'],
#       dtype='object')

# %%
print("Column Names:", df.columns.tolist())
# Out:
# Column Names: ['date', 'cloud_cover', 'sunshine', 'global_radiation', 'max_temp', 'mean_temp', 'min_temp', 'precipitation', 'pressure', 'snow_depth']

# %%
print("\nData Types:\n", df.dtypes)
# Out:
# Data Types:
#  date                  int64
# cloud_cover         float64
# sunshine            float64
# global_radiation    float64
# max_temp            float64
# mean_temp           float64
# min_temp            float64
# precipitation       float64
# pressure            float64
# snow_depth          float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#                date   cloud_cover      sunshine  global_radiation  \
# count  1.534100e+04  15322.000000  15341.000000      15322.000000
# mean   1.999567e+07      5.268242      4.350238        118.756951
# std    1.212176e+05      2.070072      4.028339         88.898272
# min    1.979010e+07      0.000000      0.000000          8.000000
# 25%    1.989070e+07      4.000000      0.500000         41.000000
# 50%    2.000010e+07      6.000000      3.500000         95.000000
# 75%    2.010070e+07      7.000000      7.200000        186.000000
# max    2.020123e+07      9.000000     16.000000        402.000000
#
#            max_temp     mean_temp      min_temp  precipitation       pressure  \
# count  15335.000000  15305.000000  15339.000000   15335.000000   15337.000000
# mean      15.388777     11.475511      7.559867       1.668634  101536.605594
# std        6.554754      5.729709      5.326756       3.738540    1049.722604
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  int64
#  1   cloud_cover       15322 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15322 non-null  float64
#  4   max_temp          15335 non-null  float64
#  5   mean_temp         15305 non-null  float64
#  6   min_temp          15339 non-null  float64
#  7   precipitation     15335 non-null  float64
#  8   pressure          15337 non-null  float64
#  9   snow_depth        13900 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 1.2 MB

# %%
print("\nShape of DataFrame:", df.shape)
# Out:
# Shape of DataFrame: (15341, 10)

# %%
print(df.isnull().sum())
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# dtype: int64

# %%
df.isnull()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      False        False     False             False     False      False
# 1      False        False     False             False     False      False
# 2      False        False     False             False     False      False
# 3      False        False     False             False     False      False
# 4      False        False     False             False     False      False
# ...      ...          ...       ...               ...       ...        ...
# 15336  False        False     False             False     False      False
# 15337  False        False     False             False     False      False
# 15338  False        False     False             False     False      False
# 15339  False        False     False             False     False      False
# 15340  False        False     False             False     False      False
#
#        min_temp  precipitation  pressure  snow_depth
# ...

# %%
# Visualize missing values usig heat map and bar chart
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# Plot the bar chart
plt.figure(figsize=(10, 6))
missing_count.plot(kind='bar', color='skyblue')
plt.title('Missing Values Count per Column')
plt.xlabel('Columns')
plt.ylabel('Count of Missing Values')
plt.show()

# %%
# Distribution of Numerical Features
print("\nDistribution of Numerical Features")
print("--------------------------------------")
numerical_features = df.loc[ : , df.columns != 'date'].select_dtypes(include=['float64', 'int64']).columns

# Plot distributions
for col in numerical_features:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col].dropna(), kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# 4. Distribution of Numerical Features
# --------------------------------------

# %%
# Time Series Analysis
print("\nTime Series Analysis")
print("-----------------------")
# Assuming 'date' is in YYYYMMDD format
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
# Plot time series for each numerical feature
# for col in numerical_features.drop('date'):
for col in numerical_features:
    plt.figure(figsize=(12, 6))
    sns.lineplot(x='date', y=col, data=df)
    plt.title(f'Time Series of {col}')
    plt.xlabel('Date')
    plt.ylabel(col)
    plt.show()
# Out:
# Time Series Analysis
# -----------------------

# %%
# Correlation Analysis
print("\nCorrelation Analysis")
print("------------------------")
correlation_matrix = df.corr()
print(correlation_matrix)

# Visualize correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Analysis
# ------------------------
#                   cloud_cover  sunshine  global_radiation  max_temp  \
# cloud_cover          1.000000 -0.738291         -0.485973 -0.212224
# sunshine            -0.738291  1.000000          0.852632  0.472182
# global_radiation    -0.485973  0.852632          1.000000  0.690946
# max_temp            -0.212224  0.472182          0.690946  1.000000
# mean_temp           -0.110556  0.396535          0.635432  0.912200
# min_temp             0.048838  0.219082          0.478119  0.810514
# precipitation        0.235269 -0.231636         -0.162668 -0.071799
# pressure            -0.241955  0.226943          0.150078  0.100455
# snow_depth          -0.001256 -0.034222         -0.061781 -0.130594
#
#                   mean_temp  min_temp  precipitation  pressure  snow_depth
# cloud_cover       -0.110556  0.048838       0.235269 -0.241955   -0.001256
# sunshine           0.396535  0.219082      -0.231636  0.226943   -0.034222
# ...

# %%
mean_temp_arr =  correlation_matrix['mean_temp']
mean_temp_arr.index.tolist()

df_meanT_corr = pd.DataFrame({"mean_temp": mean_temp_arr.values.tolist()},
                  index=mean_temp_arr.index.tolist())

df_meanT_corr
# Out:
#                   mean_temp
# cloud_cover       -0.110556
# sunshine           0.396535
# global_radiation   0.635432
# max_temp           0.912200
# mean_temp          1.000000
# min_temp           0.955593
# precipitation     -0.010462
# pressure           0.004764
# snow_depth        -0.154945

# %%
# Visualize correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(df_meanT_corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
df['date'] = pd.to_datetime(df["date"],format='%Y%m%d')
df['year'] = df['date'].dt.year
df['month'] = df["date"].dt.month.map("{:02}".format)

# %%
df.head()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0 1979-01-01          2.0       7.0              52.0       2.3       -4.1
# 1 1979-01-02          6.0       1.7              27.0       1.6       -2.6
# 2 1979-01-03          5.0       0.0              13.0       1.3       -2.8
# 3 1979-01-04          8.0       0.0              13.0      -0.3       -2.6
# 4 1979-01-05          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth  year month
# 0      -7.5            0.4  101900.0         9.0  1979    01
# 1      -7.5            0.0  102530.0         8.0  1979    01
# 2      -7.2            0.0  102050.0         4.0  1979    01
# 3      -6.5            0.0  100840.0         2.0  1979    01
# 4      -1.4            0.0  102250.0         1.0  1979    01

# %%
sns.lineplot(x="month", y="mean_temp", data=df) 
plt.show()

# %%
sns.lineplot(x="year", y="mean_temp", data=df, ci=None)
plt.show()

# %%
# Aggregate and calculate average metrics
weather_metrics = ['cloud_cover', 'sunshine', 'global_radiation', 'max_temp', 'mean_temp', 'min_temp', 'precipitation', 'pressure', 'snow_depth']
weather_by_month = df.groupby(['year', 'month'], as_index = False)[weather_metrics].mean()

# %%
weather_by_month
# Out:
#      year  month  cloud_cover  sunshine  global_radiation   max_temp  \
# 0    1979      1     5.724138  1.887097         29.032258   4.116129
# 1    1979      2     6.360000  1.889286         45.214286   4.532143
# 2    1979      3     5.967742  3.212903         93.354839   9.238710
# 3    1979      4     6.133333  3.543333        134.166667  12.520000
# 4    1979      5     5.290323  6.470968        204.064516  16.206452
# ..    ...    ...          ...       ...               ...        ...
# 499  2020      8     5.000000  6.135484        210.741935  25.200000
# 500  2020      9     4.200000  6.540000        170.000000  21.693333
# 501  2020     10     5.774194  1.887097         72.516129  14.970000
# 502  2020     11     5.933333  1.716667         43.166667  12.636667
# 503  2020     12     5.466667  1.425806         27.967742   8.325806
#
#      mean_temp   min_temp  precipitation       pressure  snow_depth
# 0     0.616129  -2.551613       1.932258  101214.838710    1.354839
# ...

# %%
sns.lineplot(x="global_radiation", y="mean_temp", data=weather_by_month, ci=None)
plt.show()

# %%
weather_by_month
# Out:
#      year month  cloud_cover  sunshine  global_radiation   max_temp  \
# 0    1979    01     5.724138  1.887097         29.032258   4.116129
# 1    1979    02     6.360000  1.889286         45.214286   4.532143
# 2    1979    03     5.967742  3.212903         93.354839   9.238710
# 3    1979    04     6.133333  3.543333        134.166667  12.520000
# 4    1979    05     5.290323  6.470968        204.064516  16.206452
# ..    ...   ...          ...       ...               ...        ...
# 499  2020    08     5.000000  6.135484        210.741935  25.200000
# 500  2020    09     4.200000  6.540000        170.000000  21.693333
# 501  2020    10     5.774194  1.887097         72.516129  14.970000
# 502  2020    11     5.933333  1.716667         43.166667  12.636667
# 503  2020    12     5.466667  1.425806         27.967742   8.325806
#
#      mean_temp   min_temp  precipitation       pressure  snow_depth
# 0     0.616129  -2.551613       1.932258  101214.838710    1.354839
# ...

# %%
df_weather.drop(["mean_temp", "date"], axis=1).columns.to_list()
# Out:
# ['cloud_cover',
#  'sunshine',
#  'global_radiation',
#  'max_temp',
#  'min_temp',
#  'precipitation',
#  'pressure',
#  'snow_depth',
#  'year',
#  'month']

# %%
weather_all_features = df_weather.drop(["mean_temp", "date"], axis=1).columns.to_list()
weather_features = ['month', 'max_temp', 'min_temp', 'global_radiation', 'sunshine', 'cloud_cover', 'snow_depth']
# weather_features = ['month', 'cloud_cover', 'sunshine', 'precipitation', 'pressure', 'global_radiation']
weather_target = "mean_temp"
df_weather = df.copy()
df_weather['mean_temp'] = df_weather.fillna(df_weather['mean_temp'].mean())['mean_temp']

# %%
df_weather.isnull().sum()
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp              0
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# year                   0
# month                  0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# year                   0
# month                  0
# dtype: int64

# %%
df_weather.head()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0 1979-01-01          2.0       7.0              52.0       2.3       -4.1
# 1 1979-01-02          6.0       1.7              27.0       1.6       -2.6
# 2 1979-01-03          5.0       0.0              13.0       1.3       -2.8
# 3 1979-01-04          8.0       0.0              13.0      -0.3       -2.6
# 4 1979-01-05          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth  year month
# 0      -7.5            0.4  101900.0         9.0  1979    01
# 1      -7.5            0.0  102530.0         8.0  1979    01
# 2      -7.2            0.0  102050.0         4.0  1979    01
# 3      -6.5            0.0  100840.0         2.0  1979    01
# 4      -1.4            0.0  102250.0         1.0  1979    01

# %%
df_weather.dtypes
# Out:
# date                datetime64[ns]
# cloud_cover                float64
# sunshine                   float64
# global_radiation           float64
# max_temp                   float64
# mean_temp                  float64
# min_temp                   float64
# precipitation              float64
# pressure                   float64
# snow_depth                 float64
# year                         int64
# month                        int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor


from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %%
# Subset feature and target sets
X = df_weather[weather_all_features]    
# X = df_weather[weather_features]  
y = df_weather[weather_target]
    
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print(X[0:2])
print(type(X))
print("The selected features are : ", X_train.columns)
feature_index = X_train.columns
    
# Impute missing values
imputer = SimpleImputer(strategy="mean")
# Fit on the training data
X_train = imputer.fit_transform(X_train)
# Transform on the test data
X_test  = imputer.transform(X_test)
    
# Scale the data
scaler = StandardScaler()
# Fit on the training data
X_train = scaler.fit_transform(X_train)
# Transform on the test data
X_test = scaler.transform(X_test)
# Out:
#    cloud_cover  sunshine  global_radiation  max_temp  min_temp  precipitation  \
# 0          2.0       7.0              52.0       2.3      -7.5            0.4
# 1          6.0       1.7              27.0       1.6      -7.5            0.0
#
#    pressure  snow_depth  year month
# 0  101900.0         9.0  1979    01
# 1  102530.0         8.0  1979    01
# <class 'pandas.core.frame.DataFrame'>
# The selected features are :  Index(['cloud_cover', 'sunshine', 'global_radiation', 'max_temp', 'min_temp',
#        'precipitation', 'pressure', 'snow_depth', 'year', 'month'],
#       dtype='object')

# %%
# run a Principal Component Analysis (PCA) on the scaled data
# pca = PCA(n_components=7)
pca = PCA()
principal_components = pca.fit_transform(X_train)
expl_variance = pca.explained_variance_ratio_

# Plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(1, len(expl_variance) + 1), expl_variance)
ax.set_xlabel('Principal Component #')
ax.set_ylabel('Explained Variance Ratio')
ax.set_title('Explained Variance by Principal Components')
plt.show()

# Calculate loadings
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
loadings_df = pd.DataFrame(loadings, columns=[f'PC{i+1}' for i in range(loadings.shape[1])], index=feature_index)

# Print the loadings
print("PCA Loadings:")
print(loadings_df)

# Plot the loadings as a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(loadings_df, annot=True, cmap='coolwarm', center=0)
plt.title('PCA Loadings Heatmap')
plt.xlabel('Principal Components')
plt.ylabel('Features')
plt.show()
# Out:
# PCA Loadings:
#                        PC1       PC2       PC3       PC4       PC5       PC6  \
# cloud_cover      -0.633881  0.490507  0.141200 -0.151867 -0.150125 -0.419686
# sunshine          0.869372 -0.295234 -0.205076 -0.051640 -0.014362  0.211515
# global_radiation  0.909084 -0.010893 -0.229985 -0.112470 -0.115252 -0.053191
# max_temp          0.803783  0.459929  0.060734 -0.059264  0.023718 -0.208617
# min_temp          0.584901  0.703539  0.093105 -0.056495  0.028904 -0.256781
# precipitation    -0.283953  0.484341 -0.523502 -0.020750 -0.058379  0.283373
# pressure          0.281882 -0.486291  0.548341  0.000673 -0.032394 -0.239355
# snow_depth       -0.114181 -0.255288 -0.359904 -0.290922  0.755357 -0.366537
# year              0.102906  0.090454 -0.099025  0.939758  0.229309 -0.167206
# month             0.077824  0.417073  0.507198 -0.057236  0.531114  0.508873
#
#                        PC7       PC8       PC9      PC10
# ...

# %%
# Calculating the commulative sum of the principle components
cum_exp_variance = np.cumsum(expl_variance)
cum_exp_variance
# Plot the cumulative explained variance and draw a dashed line at 0.85.
fig, ax = plt.subplots()
ax.plot(range(1, len(cum_exp_variance) + 1),cum_exp_variance)
ax.axhline(y=0.85, linestyle='--')

# %%
lin_reg = LinearRegression().fit(X_train, y_train)

# %%
 # Evaluate performance
y_pred_lin_reg = lin_reg.predict(X_test)
lin_reg_rmse = mean_squared_error(y_test, y_pred_lin_reg, squared=False)
lin_reg_rmse

# RMSE = 0.9245276888713514
# Subset of features ['month', 'max_temp', 'min_temp', 'global_radiation', 'sunshine', 'cloud_cover', 'snow_depth']
# - changing 'n' on PCA does not change the RMSE

# RMSE = 0.9214680369231354
# All features (except date)
# - changing 'n' on PCA does not change the RMSE
# Out:
# 0.9214680369231354

# %%
# weather_features = ['month', 'max_temp', 'min_temp', 'global_radiation', 'sunshine', 'cloud_cover', 'snow_depth']
# weather_target = "mean_temp"

# df_weather = df.dropna(subset=['mean_temp'])
# df_weather
# Out:
#             date  cloud_cover  sunshine  global_radiation  max_temp  \
# 0     1979-01-01          2.0       7.0              52.0       2.3
# 1     1979-01-02          6.0       1.7              27.0       1.6
# 2     1979-01-03          5.0       0.0              13.0       1.3
# 3     1979-01-04          8.0       0.0              13.0      -0.3
# 4     1979-01-05          6.0       2.0              29.0       5.6
# ...          ...          ...       ...               ...       ...
# 15336 2020-12-27          1.0       0.9              32.0       7.5
# 15337 2020-12-28          7.0       3.7              38.0       3.6
# 15338 2020-12-29          7.0       0.0              21.0       4.1
# 15339 2020-12-30          6.0       0.4              22.0       5.6
# 15340 2020-12-31          7.0       1.3              34.0       1.5
#
#        mean_temp  min_temp  precipitation  pressure  snow_depth  year month
# ...

# %%
# # Impute missing values
# imputer = SimpleImputer(missing_values = np.NaN, strategy='mean')
# # Fit on the training data
# # imputer = imputer.fit(df_weather)
# # df_imputed=imputer.transform(df_weather[weather_features + [ 'pressure', 'precipitation'])
# imputer = imputer.fit(df_weather.iloc[:,1:10])
# df_weather.iloc[:,1:10]=imputer.transform(df_weather.iloc[:,1:10])
# df_weather
# Out:
#             date  cloud_cover  sunshine  global_radiation  max_temp  \
# 0     1979-01-01          2.0       7.0              52.0       2.3
# 1     1979-01-02          6.0       1.7              27.0       1.6
# 2     1979-01-03          5.0       0.0              13.0       1.3
# 3     1979-01-04          8.0       0.0              13.0      -0.3
# 4     1979-01-05          6.0       2.0              29.0       5.6
# ...          ...          ...       ...               ...       ...
# 15336 2020-12-27          1.0       0.9              32.0       7.5
# 15337 2020-12-28          7.0       3.7              38.0       3.6
# 15338 2020-12-29          7.0       0.0              21.0       4.1
# 15339 2020-12-30          6.0       0.4              22.0       5.6
# 15340 2020-12-31          7.0       1.3              34.0       1.5
#
#        mean_temp  min_temp  precipitation  pressure  snow_depth  year month
# ...

# %%
print(df_weather.isnull().sum())
# Out:
# date                0
# cloud_cover         0
# sunshine            0
# global_radiation    0
# max_temp            0
# mean_temp           0
# min_temp            0
# precipitation       0
# pressure            0
# snow_depth          0
# year                0
# month               0
# dtype: int64

# %%
# train_dicts = df_weather[weather_features].to_dict(orient='records')

# dv = DictVectorizer()
# X_train = dv.fit_transform(train_dicts)

# target = 'mean_temp'
# y_train = df_weather[target].values

# lr = LinearRegression()
# lr.fit(X_train, y_train)

# y_pred = lr.predict(X_train)

# root_mean_squared_error(y_train, y_pred)
# Out:
# 0.9172660540105572

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()

# %%
# !pip install pandas scikit-learn xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 186.4 kB/s eta 0:00:0000:0100:15
# ...
#
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
X_train[0]
# Out:
# array([ 0.84370023, -0.85949541, -0.6812112 , -0.19437673, -1.3407806 ,
#         0.62739549, -0.29301548, -0.07219102, -1.52441019, -1.01831619])

# %%
X_test[0]
# Out:
# array([-0.12196702, -0.16398363,  0.62150186,  0.47499953,  1.84735748,
#         2.30782877,  0.34656192, -0.07219102, -0.86505667, -0.44003818])

# %%
# XGBoost Model
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective ='reg:squarederror', random_state=42)
xgb_model.fit(X_train, y_train)
pred_labels_xgb = xgb_model.predict(X_test)
print('prediction Labels for XGBoost Model:',pred_labels_xgb)
# Out:
# prediction Labels for XGBoost Model: [20.772375   6.2019095  7.254516  ...  3.1473284 18.829834   6.9448304]

# %%
 mean_squared_error(y_test, pred_labels_xgb, squared=False)
# Out:
# 0.9193251579923697
