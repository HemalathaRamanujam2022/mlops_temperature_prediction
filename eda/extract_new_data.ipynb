# %%
import pandas as pd
import numpy as np

# %%
input_file = "../data/london_weather.csv"
df = pd.read_csv(input_file, parse_dates=True)

# %%
df['date'].min()
# Out:
# 19790101

# %%
df.dtypes
# Out:
# date                  int64
# cloud_cover         float64
# sunshine            float64
# global_radiation    float64
# max_temp            float64
# mean_temp           float64
# min_temp            float64
# precipitation       float64
# pressure            float64
# snow_depth          float64
# dtype: object

# %%
df['date'].max()
# Out:
# 20201231

# %%
df.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
df.tail()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 15336  20201227          1.0       0.9              32.0       7.5        7.5
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15338  20201229          7.0       0.0              21.0       4.1        2.6
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
# 15340  20201231          7.0       1.3              34.0       1.5       -0.8
#
#        min_temp  precipitation  pressure  snow_depth
# 15336       7.6            2.0   98000.0         NaN
# 15337      -1.3            0.2   97370.0         NaN
# 15338       1.1            0.0   98830.0         NaN
# 15339      -0.1            0.0  100200.0         NaN
# 15340      -3.1            0.0  100500.0         NaN

# %%
df_mean_temp = pd.read_csv("../data/raw_data/mean_temp.csv", parse_dates=True)

# %%
df_mean_temp.head()
# Out:
#        date   tg  mean_temp
# 0  19600101  106       10.6
# 1  19600102   61        6.1
# 2  19600103   84        8.4
# 3  19600104   94        9.4
# 4  19600105   89        8.9

# %%
df_min_temp = pd.read_csv("../data/raw_data/min_temp.csv", parse_dates=True)

# %%
df_max_temp = pd.read_csv("../data/raw_data/max_temp.csv", parse_dates=True)

# %%
df_cloud_cover = pd.read_csv("../data/raw_data/cloud_cover.csv", parse_dates=True)

# %%
df_global_radiation = pd.read_csv("../data/raw_data/global_radiation.csv", parse_dates=True)

# %%
df_pressure = pd.read_csv("../data/raw_data/pressure.csv", parse_dates=True)

# %%
df_precipitation = pd.read_csv("../data/raw_data/precipitation.csv", parse_dates=True)

# %%
df_sunshine = pd.read_csv("../data/raw_data/sunshine.csv", parse_dates=True)

# %%
df_snow_depth= pd.read_csv("../data/raw_data/snow_depth.csv", parse_dates=True)

# %%
dfs = [df_cloud_cover, df_sunshine, df_global_radiation, df_max_temp, df_mean_temp, df_min_temp, df_precipitation, df_pressure, df_snow_depth]

# %%
import functools as ft
df_final = ft.reduce(lambda left, right: pd.merge(left, right, on='date'), dfs)

# %%
df_final.head()
# Out:
#        date  cc  cloud_cover  ss  sunshine  qq  global_radiation   tx  \
# 0  19600101   7            7   0       0.0  13                13   83
# 1  19600102   7            7   0       0.0  13                13  106
# 2  19600103   8            8   1       0.1  15                15  122
# 3  19600104   8            8   0       0.0  13                13   89
# 4  19600105   5            5  21       2.1  30                30   72
#
#    max_temp   tg  mean_temp  tn  min_temp  rr  precipitation     pp  pressure  \
# 0       8.3  106       10.6  94       3.9  22            2.2  10010    100100
# 1      10.6   61        6.1  39       6.1  23            2.3  10051    100510
# 2      12.2   84        8.4  61       6.7   7            0.7  10166    101660
# 3       8.9   94        9.4  67       8.9   0            0.0  10230    102300
# 4       7.2   89        8.9  89       0.0   0            0.0  10275    102750
#
#    sd  snow_depth
# 0   0           0
# 1   0           0
# ...

# %%
df_final=df_final.drop(columns=['cc', 'ss', 'qq', 'tx', 'tg', 'tn', 'rr','pp', 'sd'])

# %%
df_final.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19600101            7       0.0                13       8.3       10.6
# 1  19600102            7       0.0                13      10.6        6.1
# 2  19600103            8       0.1                15      12.2        8.4
# 3  19600104            8       0.0                13       8.9        9.4
# 4  19600105            5       2.1                30       7.2        8.9
#
#    min_temp  precipitation  pressure  snow_depth
# 0       3.9            2.2    100100           0
# 1       6.1            2.3    100510           0
# 2       6.7            0.7    101660           0
# 3       8.9            0.0    102300           0
# 4       0.0            0.0    102750           0

# %%
df_final.tail()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 23553  20240626            0      13.0               318      25.5       23.6
# 23554  20240627            4       7.8               248      22.3       21.2
# 23555  20240628            4       7.1               237      25.2       17.3
# 23556  20240629            1      11.4               297      21.0       17.8
# 23557  20240630            8       2.3               153      25.1       17.1
#
#        min_temp  precipitation  pressure  snow_depth
# 23553      17.0            0.0    101190           0
# 23554      12.3            0.0    100930           0
# 23555      10.4            0.0    101590           0
# 23556      13.3            0.0    101380           0
# 23557       0.0            0.0    101340           0

# %%
df_final.dtypes
# Out:
# date                  int64
# cloud_cover           int64
# sunshine            float64
# global_radiation      int64
# max_temp            float64
# mean_temp           float64
# min_temp            float64
# precipitation       float64
# pressure              int64
# snow_depth            int64
# dtype: object

# %%
df_final['cloud_cover'] = df_final['cloud_cover'].astype(float)
df_final['global_radiation'] = df_final['global_radiation'].astype(float)
df_final['pressure'] = df_final['pressure'].astype(float)
df_final['snow_depth'] = df_final['snow_depth'].astype(float)

# %%
df_final.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19600101          7.0       0.0              13.0       8.3       10.6
# 1  19600102          7.0       0.0              13.0      10.6        6.1
# 2  19600103          8.0       0.1              15.0      12.2        8.4
# 3  19600104          8.0       0.0              13.0       8.9        9.4
# 4  19600105          5.0       2.1              30.0       7.2        8.9
#
#    min_temp  precipitation  pressure  snow_depth
# 0       3.9            2.2  100100.0         0.0
# 1       6.1            2.3  100510.0         0.0
# 2       6.7            0.7  101660.0         0.0
# 3       8.9            0.0  102300.0         0.0
# 4       0.0            0.0  102750.0         0.0

# %%
df_final.describe()
# Out:
#                date   cloud_cover      sunshine  global_radiation  \
# count  2.355800e+04  23558.000000  23558.000000      23558.000000
# mean   1.991817e+07   -112.746116      4.240194        107.538204
# std    1.862023e+05   1080.370362      3.983178        341.151873
# min    1.960010e+07  -9999.000000      0.000000      -9999.000000
# 25%    1.976022e+07      4.000000      0.400000         41.000000
# 50%    1.992037e+07      6.000000      3.400000         95.000000
# 75%    2.008052e+07      7.000000      7.000000        184.000000
# max    2.024063e+07      9.000000     15.800000        402.000000
#
#            max_temp     mean_temp      min_temp  precipitation       pressure  \
# count  23558.000000  23558.000000  23558.000000   23558.000000   23558.000000
# mean      15.124145      9.978279      7.319093       1.676675  101396.224213
# std        6.553061     35.913105      5.317938       3.829322    5354.189841
# ...

# %%
# We will fix those columns where the NaN has been loaded as upper 9s
df_final['cloud_cover'].replace(-9999.0, np.nan, inplace=True)
df_final['global_radiation'].replace(-9999.0, np.nan, inplace=True)
df_final['mean_temp'].replace(-999.9, np.nan, inplace=True)
df_final['pressure'].replace(-99990.0, np.nan, inplace=True)
df_final['snow_depth'].replace(-9999.0, np.nan, inplace=True)

# %%
df_final['date'] = pd.to_datetime(df_final["date"],format='%Y%m%d')
df_final['year'] = df_final['date'].dt.year
df_final['month'] = df_final["date"].dt.month

# %%
df_final.head()
# Out:
#         date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0 1960-01-01          7.0       0.0              13.0       8.3       10.6
# 1 1960-01-02          7.0       0.0              13.0      10.6        6.1
# 2 1960-01-03          8.0       0.1              15.0      12.2        8.4
# 3 1960-01-04          8.0       0.0              13.0       8.9        9.4
# 4 1960-01-05          5.0       2.1              30.0       7.2        8.9
#
#    min_temp  precipitation  pressure  snow_depth  year  month
# 0       3.9            2.2  100100.0         0.0  1960      1
# 1       6.1            2.3  100510.0         0.0  1960      1
# 2       6.7            0.7  101660.0         0.0  1960      1
# 3       8.9            0.0  102300.0         0.0  1960      1
# 4       0.0            0.0  102750.0         0.0  1960      1

# %%
# df_final['date'] = df_final.date.apply(lambda x: x.strftime('%Y%m%d')).astype(int)
df_final['date'] = df_final.date.apply(lambda x: x.strftime('%Y%m%d')).astype(int)

# %%
df_final.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19600101          7.0       0.0              13.0       8.3       10.6
# 1  19600102          7.0       0.0              13.0      10.6        6.1
# 2  19600103          8.0       0.1              15.0      12.2        8.4
# 3  19600104          8.0       0.0              13.0       8.9        9.4
# 4  19600105          5.0       2.1              30.0       7.2        8.9
#
#    min_temp  precipitation  pressure  snow_depth  year  month
# 0       3.9            2.2  100100.0         0.0  1960      1
# 1       6.1            2.3  100510.0         0.0  1960      1
# 2       6.7            0.7  101660.0         0.0  1960      1
# 3       8.9            0.0  102300.0         0.0  1960      1
# 4       0.0            0.0  102750.0         0.0  1960      1

# %%
df_final.dtypes
# Out:
# date                 object
# cloud_cover         float64
# sunshine            float64
# global_radiation    float64
# max_temp            float64
# mean_temp           float64
# min_temp            float64
# precipitation       float64
# pressure            float64
# snow_depth          float64
# year                  int32
# month                 int32
# dtype: object

# %%
df_final.describe()
# Out:
#                date   cloud_cover      sunshine  global_radiation  \
# count  2.355800e+04  23280.000000  23558.000000      23533.000000
# mean   1.991817e+07      5.311383      4.240194        118.274763
# std    1.862023e+05      2.052950      3.983178         88.763207
# min    1.960010e+07      0.000000      0.000000          0.000000
# 25%    1.976022e+07      4.000000      0.400000         41.000000
# 50%    1.992037e+07      6.000000      3.400000         95.000000
# 75%    2.008052e+07      7.000000      7.000000        185.000000
# max    2.024063e+07      9.000000     15.800000        402.000000
#
#            max_temp     mean_temp      min_temp  precipitation       pressure  \
# count  23558.000000  23529.000000  23558.000000   23558.000000   23542.000000
# mean      15.124145     11.222976      7.319093       1.676675  101533.093620
# std        6.553061      5.722400      5.317938       3.829322    1050.388023
# ...

# %%
df_final.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19600101          7.0       0.0              13.0       8.3       10.6
# 1  19600102          7.0       0.0              13.0      10.6        6.1
# 2  19600103          8.0       0.1              15.0      12.2        8.4
# 3  19600104          8.0       0.0              13.0       8.9        9.4
# 4  19600105          5.0       2.1              30.0       7.2        8.9
#
#    min_temp  precipitation  pressure  snow_depth  year  month
# 0       3.9            2.2  100100.0         0.0  1960      1
# 1       6.1            2.3  100510.0         0.0  1960      1
# 2       6.7            0.7  101660.0         0.0  1960      1
# 3       8.9            0.0  102300.0         0.0  1960      1
# 4       0.0            0.0  102750.0         0.0  1960      1

# %%
df_final.dtypes
# Out:
# date                datetime64[ns]
# cloud_cover                float64
# sunshine                   float64
# global_radiation           float64
# max_temp                   float64
# mean_temp                  float64
# min_temp                   float64
# precipitation              float64
# pressure                   float64
# snow_depth                 float64
# year                         int32
# month                        int32
# dtype: object

# %%
mask = (df_final['date'] >= 19790101) & (df_final['date'] <= 20201231)
print(df_final.loc[mask])
df_subset = df_final.loc[mask]
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 6940   19790101          2.0       7.0              52.0       2.3       -4.1
# 6941   19790102          6.0       1.7              27.0       1.6       -2.6
# 6942   19790103          5.0       0.0              13.0       1.3       -2.8
# 6943   19790104          8.0       0.0              13.0      -0.3       -2.6
# 6944   19790105          6.0       2.0              29.0       5.6       -0.8
# ...         ...          ...       ...               ...       ...        ...
# 22276  20201227          4.0       3.7              32.0       3.6        6.2
# 22277  20201228          7.0       0.0              38.0       4.3        1.0
# 22278  20201229          7.0       0.2              21.0       5.5        2.4
# 22279  20201230          4.0       1.3              22.0       1.4        2.5
# 22280  20201231          7.0       0.0              34.0       4.5       -0.9
#
# ...

# %%
df.isnull().sum()
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# dtype: int64

# %%
df_final.isnull().sum()
# Out:
# date                   0
# cloud_cover          278
# sunshine               0
# global_radiation      25
# max_temp               0
# mean_temp             29
# min_temp               0
# precipitation          0
# pressure              16
# snow_depth          1075
# dtype: int64

# %%
df_subset.isnull().sum()
# Out:
# date                   0
# cloud_cover           18
# sunshine               0
# global_radiation      19
# max_temp               0
# mean_temp             29
# min_temp               0
# precipitation          0
# pressure               4
# snow_depth          1075
# dtype: int64

# %%
df_subset.shape
# Out:
# (15341, 10)

# %%
df.shape
# Out:
# (15341, 10)

# %%
df_final.count()
# Out:
# date                23558
# cloud_cover         23280
# sunshine            23558
# global_radiation    23533
# max_temp            23558
# mean_temp           23529
# min_temp            23558
# precipitation       23558
# pressure            23542
# snow_depth          22483
# dtype: int64

# %%
df_final['date'].min()
# Out:
# 19600101

# %%
df_final['date'].max()
# Out:
# 20240630

# %%
df_subset[df_subset['date'] == 20091213]
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 18244  20091213          7.0       1.5              25.0       5.6        5.6
#
#        min_temp  precipitation  pressure  snow_depth
# 18244       1.7            0.2  102790.0         NaN

# %%
numeric_features =  ['max_temp', 'min_temp', 'mean_temp', 'global_radiation', 'sunshine', 'cloud_cover', 'snow_depth', 'precipitation', 'pressure']

# %%
[df[col].fillna(df[col].mean(), inplace=True) for col in numeric_features]
# Out:
# [None, None, None, None, None, None, None, None, None]

# %%
[df_subset[col].fillna(df_subset[col].mean(), inplace=True) for col in numeric_features]
# Out:
# [None, None, None, None, None, None, None, None, None]

# %%
[df_final[col].fillna(df_final[col].mean(), inplace=True) for col in numeric_features]
# Out:
# [None, None, None, None, None, None, None, None, None]

# %%
compare_df_list =  [df, df_subset]
all(x.equals(compare_df_list[0]) for x in compare_df_list)
# Out:
# False

# %%
np.allclose(df,df_subset)
# Out:
# False

# %%
df.tail(10)
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 15331  20201222     8.000000       0.0              16.0      11.7       11.7
# 15332  20201223     7.000000       0.0              23.0      14.0       12.0
# 15333  20201224     2.000000       1.3              32.0       6.1        6.1
# 15334  20201225     6.000000       3.5              40.0       4.6        2.6
# 15335  20201226     5.268242       2.1              38.0      10.0        4.9
# 15336  20201227     1.000000       0.9              32.0       7.5        7.5
# 15337  20201228     7.000000       3.7              38.0       3.6        1.1
# 15338  20201229     7.000000       0.0              21.0       4.1        2.6
# 15339  20201230     6.000000       0.4              22.0       5.6        2.7
# 15340  20201231     7.000000       1.3              34.0       1.5       -0.8
#
#        min_temp  precipitation  pressure  snow_depth
# 15331      11.7            0.6  100970.0    0.037986
# ...

# %%
df_subset.tail(10)
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 22271  20201222          8.0       0.0              16.0      13.9       10.8
# 22272  20201223          8.0       0.4              23.0       5.5       11.9
# 22273  20201224          4.0       3.2              32.0       5.5        4.6
# 22274  20201225          4.0       2.1              40.0      10.7        2.8
# 22275  20201226          7.0       0.0              38.0       6.9        5.2
# 22276  20201227          4.0       3.7              32.0       3.6        6.2
# 22277  20201228          7.0       0.0              38.0       4.3        1.0
# 22278  20201229          7.0       0.2              21.0       5.5        2.4
# 22279  20201230          4.0       1.3              22.0       1.4        2.5
# 22280  20201231          7.0       0.0              34.0       4.5       -0.9
#
#        min_temp  precipitation  pressure  snow_depth
# 22271      10.0            0.8  101040.0         0.0
# ...

# %%
df.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
df_subset.head()
# Out:
#           date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 6940  19790101          2.0       7.0              52.0       2.3       -4.1
# 6941  19790102          6.0       1.7              27.0       1.6       -2.6
# 6942  19790103          5.0       0.0              13.0       1.3       -2.8
# 6943  19790104          8.0       0.0              13.0      -0.3       -2.6
# 6944  19790105          6.0       2.0              29.0       5.6       -0.8
#
#       min_temp  precipitation  pressure  snow_depth
# 6940      -7.5            0.4  101900.0         9.0
# 6941      -7.2            0.0  102530.0         8.0
# 6942      -6.5            0.0  102050.0         4.0
# 6943      -1.4            0.0  100840.0         2.0
# 6944      -6.6            0.0  102250.0         1.0

# %%
# Create separate datasets for years from 2021 - 2023
mask = (df_final['date'] >= 20210101) & (df_final['date'] <= 20211231)
print(df_final.loc[mask])
df_2021 = df_final.loc[mask]
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 22281  20210101          8.0       0.0              16.0       5.2        1.4
# 22282  20210102          7.0       1.5              17.0       5.9        2.6
# 22283  20210103          8.0       0.6              32.0       5.4        3.3
# 22284  20210104          8.0       0.0              27.0       4.6        4.0
# 22285  20210105          8.0       0.0              17.0       6.1        3.2
# ...         ...          ...       ...               ...       ...        ...
# 22641  20211227          8.0       0.0              12.0      11.8        8.5
# 22642  20211228          8.0       0.1              14.0      15.3       10.0
# 22643  20211229          6.0       0.0              12.0      15.0       11.2
# 22644  20211230          8.0       0.0              12.0      15.3       12.4
# 22645  20211231          7.0       0.9              22.0      15.7       13.8
#
# ...

# %%
mask = (df_final['date'] >= 20220101) & (df_final['date'] <= 20221231)
print(df_final.loc[mask])
df_2022 = df_final.loc[mask]
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 22646  20220101          7.0       0.8              35.0      12.3       14.0
# 22647  20220102          6.0       0.3              29.0      10.8       11.4
# 22648  20220103          6.0       0.0              25.0       7.9        9.8
# 22649  20220104          6.0       0.0              22.0       6.6        7.7
# 22650  20220105          0.0       5.1              27.0       7.4        3.8
# ...         ...          ...       ...               ...       ...        ...
# 23006  20221227          6.0       0.5              18.0      12.0        6.7
# 23007  20221228          8.0       0.0              12.0       9.8        8.8
# 23008  20221229          4.0       1.5              25.0      14.1        8.9
# 23009  20221230          7.0       0.1              14.0      14.0        9.3
# 23010  20221231          8.0       0.0              13.0      12.3       11.4
#
# ...

# %%
mask = (df_final['date'] >= 20230101) & (df_final['date'] <= 20231231)
print(df_final.loc[mask])
df_2023 = df_final.loc[mask]
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 23011  20230101          7.0       0.0              21.0       9.3       11.2
# 23012  20230102          3.0       5.2              44.0      13.4        7.2
# 23013  20230103          7.0       0.0               9.0      13.9        7.8
# 23014  20230104          6.0       0.4              17.0      13.5       11.6
# 23015  20230105          8.0       0.4              28.0      12.7       11.2
# ...         ...          ...       ...               ...       ...        ...
# 23371  20231227          8.0       0.0              12.0      12.6        8.9
# 23372  20231228          7.0       0.2              15.0      11.9       11.2
# 23373  20231229          6.0       0.7              20.0      12.2       10.6
# 23374  20231230          7.0       0.0              12.0      10.7        8.9
# 23375  20231231          7.0       0.5              18.0      12.4        8.2
#
# ...

# %%
df_2021.to_csv('../data/weather_data_2021.csv')

# %%
df_2022.to_csv('../data/weather_data_2022.csv')

# %%
df_2023.to_csv('../data/weather_data_2023.csv')

# %%
df_2021.head()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 22281  20210101          8.0       0.0              16.0       5.2        1.4
# 22282  20210102          7.0       1.5              17.0       5.9        2.6
# 22283  20210103          8.0       0.6              32.0       5.4        3.3
# 22284  20210104          8.0       0.0              27.0       4.6        4.0
# 22285  20210105          8.0       0.0              17.0       6.1        3.2
#
#        min_temp  precipitation  pressure  snow_depth  year  month
# 22281       0.0            0.6  101170.0         0.0  2021      1
# 22282       0.7            0.0  101600.0         0.0  2021      1
# 22283       2.6            0.2  101760.0         0.0  2021      1
# 22284       1.8            0.0  101950.0         0.0  2021      1
# 22285       2.7            0.4  102010.0         0.0  2021      1

# %%
df_2022.head()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 22646  20220101          7.0       0.8              35.0      12.3       14.0
# 22647  20220102          6.0       0.3              29.0      10.8       11.4
# 22648  20220103          6.0       0.0              25.0       7.9        9.8
# 22649  20220104          6.0       0.0              22.0       6.6        7.7
# 22650  20220105          0.0       5.1              27.0       7.4        3.8
#
#        min_temp  precipitation  pressure  snow_depth  year  month
# 22646      10.5            1.2  101730.0         0.0  2022      1
# 22647       8.7            0.4  101050.0         0.0  2022      1
# 22648       7.4            0.4  100790.0         0.0  2022      1
# 22649       1.0            4.0  100150.0         0.0  2022      1
# 22650      -3.5            0.0  101390.0         0.0  2022      1

# %%
df_2023.head()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 23011  20230101          7.0       0.0              21.0       9.3       11.2
# 23012  20230102          3.0       5.2              44.0      13.4        7.2
# 23013  20230103          7.0       0.0               9.0      13.9        7.8
# 23014  20230104          6.0       0.4              17.0      13.5       11.6
# 23015  20230105          8.0       0.4              28.0      12.7       11.2
#
#        min_temp  precipitation  pressure  snow_depth
# 23011       5.2            4.6  100800.0         0.0
# 23012       2.1            0.4  101690.0         0.0
# 23013       9.2            3.0  101860.0         0.0
# 23014       8.9            0.2  101460.0         0.0
# 23015       6.3            2.4  101860.0         0.0

# %%
df_2021.tail()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 22641  20211227          8.0       0.0              12.0      11.8        8.5
# 22642  20211228          8.0       0.1              14.0      15.3       10.0
# 22643  20211229          6.0       0.0              12.0      15.0       11.2
# 22644  20211230          8.0       0.0              12.0      15.3       12.4
# 22645  20211231          7.0       0.9              22.0      15.7       13.8
#
#        min_temp  precipitation  pressure  snow_depth
# 22641       8.2            5.0   99210.0         0.0
# 22642       7.1            1.2   99260.0         0.0
# 22643       9.8            0.8  100430.0         0.0
# 22644      12.4            2.6  101260.0         0.0
# 22645      12.3            0.0  101670.0         0.0

# %%
df_2022.tail()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 23006  20221227          6.0       0.5              18.0      12.0        6.7
# 23007  20221228          8.0       0.0              12.0       9.8        8.8
# 23008  20221229          4.0       1.5              25.0      14.1        8.9
# 23009  20221230          7.0       0.1              14.0      14.0        9.3
# 23010  20221231          8.0       0.0              13.0      12.3       11.4
#
#        min_temp  precipitation  pressure  snow_depth
# 23006       5.7            6.2  101930.0         0.0
# 23007       8.1            3.6  100190.0         0.0
# 23008       4.5            0.6  100100.0         0.0
# 23009       8.9            1.8   99710.0         0.0
# 23010      10.0            6.2   99950.0         0.0

# %%
df_2023.tail()
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 23371  20231227          8.0       0.0              12.0      12.6        8.9
# 23372  20231228          7.0       0.2              15.0      11.9       11.2
# 23373  20231229          6.0       0.7              20.0      12.2       10.6
# 23374  20231230          7.0       0.0              12.0      10.7        8.9
# 23375  20231231          7.0       0.5              18.0      12.4        8.2
#
#        min_temp  precipitation  pressure  snow_depth
# 23371       9.7            4.6  100670.0         0.0
# 23372       9.2            4.8  100510.0         0.0
# 23373       5.6            0.0  100710.0         0.0
# 23374       5.7            5.6  100460.0         0.0
# 23375       6.4            1.6   98910.0         0.0
